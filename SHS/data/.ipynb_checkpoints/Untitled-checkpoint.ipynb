# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
data1=np.loadtxt??

# %%
data1=np.loadtxt("./data.csv",delimiter=',');

# %%
data1.shape
# Out:
# (1097, 6)

# %%
data2=np.loadtxt("./ahrsrobust.csv",delimiter=',');

# %%
data3=np.loadtxt("./gyro.csv",delimiter=',');

# %%
data4=np.loadtxt("./jifenahrsrobust.csv",delimiter=',');

# %%
plt.figure()
plt.plot(data1[:,0],data1[:,1])
plt.plot(data2[:,0],data2[:,1])
plt.plot(data3[:,0],data3[:,1])
plt.grid()
plt.show()
