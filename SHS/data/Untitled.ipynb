# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
data1=np.loadtxt??

# %%
data1=np.loadtxt("./data.csv",delimiter=',');

# %%
data1.shape
# Out:
# (1097, 6)

# %%
data2=np.loadtxt("./ahrsrobust.csv",delimiter=',');

# %%
data3=np.loadtxt("./gyro.csv",delimiter=',');

# %%
data4=np.loadtxt("./jifenahrsrobust.csv",delimiter=',');

# %%
plt.figure(figsize=(25,25))
plt.plot(data1[:,0],data1[:,1],label='jfgyro')
plt.plot(data2[:,0],data2[:,1],label='ahrsrobust')
plt.plot(data3[:,0],data3[:,1],label='gyro')
plt.plot(data4[:,0],data4[:,1],label='jfahrsr')
plt.grid()
plt.legend()
plt.show()

# %%
plt.legend??
